# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
import numpy as np
import statsmodels.api as sm

# %%
data = pd.read_csv('final_file.csv', parse_dates=['order_date','ship_date'], date_parser=lambda x: pd.to_datetime(x, format='mixed', dayfirst=True))

# Check the data
import warnings
warnings.filterwarnings("ignore")

# %%
data.head()
# Out:
#               city  customer_age      customer_name customer_segment  \
# 0    Stevens Point            60      Dennis Bolton        Corporate
# 1    Stevens Point            60      Dennis Bolton        Corporate
# 2        Grapevine            49  Anthony Garverick   Small Business
# 3            Tempe            30     Anne McFarland         Consumer
# 4  Upper Arlington            84     Sara Luxemburg        Corporate
#
#    discount order_date                              order_id order_priority  \
# 0      0.17 2020-02-29  a42c8cff-5757-4e94-80b0-807538fefd25  Not Specified
# 1      0.17 2020-02-29  1c37f301-564f-40ff-bd7d-73a6c06ede1a  Not Specified
# 2      0.05 2021-11-11  ec649eae-535d-4154-b3ef-c4405bd59da9         Medium
# 3      0.05 2020-08-02  efdcbace-5320-4005-95e2-4c94a896dc8c  Not Specified
# 4      0.25 2020-09-26  6b88eca0-426a-4fd4-83c6-1657c43f94a0           High
#
#    order_quantity  product_base_margin  ...  product_sub_category  \
# 0               7                 0.55  ...    Chairs & Chairmats
# 1               7                 0.55  ...    Chairs & Chairmats
# 2              42                 0.69  ...                Tables
# 3              30                 0.37  ...                 Paper
# 4              31                 0.77  ...  Computer Peripherals
#
#         profit   region    sales  ship_date       ship_mode  shipping_cost  \
# 0  19559.92268  Central    21.84 2020-03-02  Delivery Truck       3.772509
# 1  19559.92268  Central  1811.67 2020-03-07  Delivery Truck     816.340893
# 2   7535.93880  Central  6129.06 2021-11-15  Delivery Truck    4530.505983
# 3  18860.92419     West   198.90 2020-08-08     Regular Air     128.731505
# 4  20175.51620     East   243.97 2020-09-30     Express Air      17.811073
#
#        state unit_price  zip_code
# 0  Wisconsin       3.29   54481.0
# 1  Wisconsin     258.98   54481.0
# 2      Texas     145.98   76051.0
# 3    Arizona       6.68   85281.0
# 4       Ohio       8.12   43221.0
#
# [5 rows x 23 columns]

# %%
data.tail()
# Out:
#                      city  customer_age   customer_name customer_segment  \
# 1009313          Tiverton            55   Roland Murray        Corporate
# 1009314    Vestavia Hills            63       Ed Jacobs        Corporate
# 1009315        Fort Worth            79    Eugene Moren   Small Business
# 1009316  Huntington Beach            62  Randy Ferguson   Small Business
# 1009317          Saratoga            62  Liz Willingham   Small Business
#
#          discount order_date                              order_id  \
# 1009313      0.15 2019-07-13  53d46dc3-d6cb-4a55-8626-1614aa9f3d77
# 1009314      0.18 2020-04-23  243e3616-443d-4f35-8534-8a680f364188
# 1009315      0.25 2020-06-18  c2cff208-474b-47d8-a956-c0703d5a11ba
# 1009316      0.09 2020-06-07  3b3e237d-bf45-4b07-aecd-8e4e47ca47ec
# 1009317      0.05 2020-12-01  b317e74c-9891-4c0d-9977-aaf767b2721e
#
#         order_priority  order_quantity  product_base_margin  ...  \
# 1009313         Medium              50                 0.58  ...
# 1009314            Low              31                 0.59  ...
# 1009315         Medium               2                 0.37  ...
# 1009316       Critical              24                 0.81  ...
# 1009317       Critical              11                 0.82  ...
#
#                    product_sub_category       profit   region    sales  \
# 1009313          Storage & Organization  15732.04569     East  1406.50
# 1009314          Storage & Organization  20701.07035    South   241.80
# 1009315  Binders and Binder Accessories  -2951.55084  Central     3.82
# 1009316          Storage & Organization  22180.49814     West  1941.36
# 1009317          Storage & Organization   9140.72233     West  1114.96
#
#          ship_date    ship_mode  shipping_cost         state unit_price  \
# 1009313 2019-07-21  Express Air    1092.369372  Rhode Island      28.28
# 1009314 2020-04-28  Express Air      44.258342       Alabama       7.98
# 1009315 2020-06-27  Express Air       0.106669         Texas       2.16
# 1009316 2020-06-17  Express Air     324.770871    California      80.98
# 1009317 2020-12-09  Regular Air     125.152699    California     101.41
#
#          zip_code
# 1009313    2878.0
# 1009314   35216.0
# 1009315   76106.0
# 1009316   92646.0
# 1009317   95070.0
#
# [5 rows x 23 columns]

# %%
# Check the data types
data.dtypes
# Out:
# city                            object
# customer_age                     int64
# customer_name                   object
# customer_segment                object
# discount                       float64
# order_date              datetime64[ns]
# order_id                        object
# order_priority                  object
# order_quantity                   int64
# product_base_margin            float64
# product_category                object
# product_container               object
# product_name                    object
# product_sub_category            object
# profit                         float64
# region                          object
# sales                          float64
# ship_date               datetime64[ns]
# ship_mode                       object
# shipping_cost                  float64
# state                           object
# unit_price                     float64
# zip_code                       float64
# dtype: object

# %% [markdown]
# ### Outlier Handling

# %%
data2=data.copy()
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data2['sales'].quantile(0.25)
Q3 = data2['sales'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Define outliers based on 1.5*IQR rule
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df10 = data2['sales'].apply(lambda x: (x if x < lower_bound else None ) or (x if x > upper_bound else None))
print(df10.count())
# Replace outliers with boundary values
data2['sales'] = data2['sales'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# Print DataFrame after replacing outliers
#print("DataFrame after replacing outliers:")
print(data2)
# Out:
# 124888
#                      city  customer_age      customer_name customer_segment  \
# 0           Stevens Point            60      Dennis Bolton        Corporate
# 1           Stevens Point            60      Dennis Bolton        Corporate
# 2               Grapevine            49  Anthony Garverick   Small Business
# 3                   Tempe            30     Anne McFarland         Consumer
# 4         Upper Arlington            84     Sara Luxemburg        Corporate
# ...                   ...           ...                ...              ...
# 1009313          Tiverton            55      Roland Murray        Corporate
# 1009314    Vestavia Hills            63          Ed Jacobs        Corporate
# 1009315        Fort Worth            79       Eugene Moren   Small Business
# 1009316  Huntington Beach            62     Randy Ferguson   Small Business
# 1009317          Saratoga            62     Liz Willingham   Small Business
#
#          discount order_date                              order_id  \
# 0            0.17 2020-02-29  a42c8cff-5757-4e94-80b0-807538fefd25
# 1            0.17 2020-02-29  1c37f301-564f-40ff-bd7d-73a6c06ede1a
# 2            0.05 2021-11-11  ec649eae-535d-4154-b3ef-c4405bd59da9
# 3            0.05 2020-08-02  efdcbace-5320-4005-95e2-4c94a896dc8c
# 4            0.25 2020-09-26  6b88eca0-426a-4fd4-83c6-1657c43f94a0
# ...           ...        ...                                   ...
# 1009313      0.15 2019-07-13  53d46dc3-d6cb-4a55-8626-1614aa9f3d77
# 1009314      0.18 2020-04-23  243e3616-443d-4f35-8534-8a680f364188
# 1009315      0.25 2020-06-18  c2cff208-474b-47d8-a956-c0703d5a11ba
# 1009316      0.09 2020-06-07  3b3e237d-bf45-4b07-aecd-8e4e47ca47ec
# 1009317      0.05 2020-12-01  b317e74c-9891-4c0d-9977-aaf767b2721e
#
#         order_priority  order_quantity  product_base_margin  ...  \
# 0        Not Specified               7                 0.55  ...
# 1        Not Specified               7                 0.55  ...
# 2               Medium              42                 0.69  ...
# 3        Not Specified              30                 0.37  ...
# 4                 High              31                 0.77  ...
# ...                ...             ...                  ...  ...
# 1009313         Medium              50                 0.58  ...
# 1009314            Low              31                 0.59  ...
# 1009315         Medium               2                 0.37  ...
# 1009316       Critical              24                 0.81  ...
# 1009317       Critical              11                 0.82  ...
#
#                    product_sub_category       profit   region    sales  \
# 0                    Chairs & Chairmats  19559.92268  Central    21.84
# 1                    Chairs & Chairmats  19559.92268  Central  1811.67
# 2                                Tables   7535.93880  Central  4408.89
# 3                                 Paper  18860.92419     West   198.90
# 4                  Computer Peripherals  20175.51620     East   243.97
# ...                                 ...          ...      ...      ...
# 1009313          Storage & Organization  15732.04569     East  1406.50
# 1009314          Storage & Organization  20701.07035    South   241.80
# 1009315  Binders and Binder Accessories  -2951.55084  Central     3.82
# 1009316          Storage & Organization  22180.49814     West  1941.36
# 1009317          Storage & Organization   9140.72233     West  1114.96
#
#          ship_date       ship_mode  shipping_cost         state unit_price  \
# 0       2020-03-02  Delivery Truck       3.772509     Wisconsin       3.29
# 1       2020-03-07  Delivery Truck     816.340893     Wisconsin     258.98
# 2       2021-11-15  Delivery Truck    4530.505983         Texas     145.98
# 3       2020-08-08     Regular Air     128.731505       Arizona       6.68
# 4       2020-09-30     Express Air      17.811073          Ohio       8.12
# ...            ...             ...            ...           ...        ...
# 1009313 2019-07-21     Express Air    1092.369372  Rhode Island      28.28
# 1009314 2020-04-28     Express Air      44.258342       Alabama       7.98
# 1009315 2020-06-27     Express Air       0.106669         Texas       2.16
# 1009316 2020-06-17     Express Air     324.770871    California      80.98
# 1009317 2020-12-09     Regular Air     125.152699    California     101.41
#
#          zip_code
# 0         54481.0
# 1         54481.0
# 2         76051.0
# 3         85281.0
# 4         43221.0
# ...           ...
# 1009313    2878.0
# 1009314   35216.0
# 1009315   76106.0
# 1009316   92646.0
# 1009317   95070.0
#
# [1009318 rows x 23 columns]

# %%
data2.shape
# Out:
# (1009318, 23)

# %% [markdown]
# ### Sample set for trial

# %%
sample = data2.sample(n=50000, random_state=42)

# %%
sample.shape
# Out:
# (50000, 23)

# %%
sample.tail()
# Out:
#                city  customer_age    customer_name customer_segment  discount  \
# 395483  Casselberry            43      Daniel Lacy      Home Office      0.14
# 970586        Mason            49   Julie Prescott      Home Office      0.04
# 56425    Kingsville            40     Bart Watters        Corporate      0.21
# 18829       Roanoke            46     Larry Blacks        Corporate      0.01
# 6998      Bremerton            55  Damala Kotsonis        Corporate      0.19
#
#        order_date                              order_id order_priority  \
# 395483 2019-04-12  8e7b8f4a-9c3e-4796-aead-aa8f26addc78       Critical
# 970586 2021-11-13  2f7422d8-5edc-4a70-9cf2-6c238c75921e           High
# 56425  2020-03-12  5155b8eb-7394-40aa-918b-357dfa6bdff0         Medium
# 18829  2022-11-23  9ec1ca49-d471-48d6-8047-a25113224e59       Critical
# 6998   2021-07-20  d49d9242-785c-4b30-a232-28a76161f332         Medium
#
#         order_quantity  product_base_margin  ...  \
# 395483              47                 0.50  ...
# 970586              24                 0.37  ...
# 56425                3                 0.44  ...
# 18829               32                 0.35  ...
# 6998                41                 0.57  ...
#
#                 product_sub_category       profit   region    sales  \
# 395483          Computer Peripherals   2154.59281    South  4408.89
# 970586                         Paper   4321.86202     East   154.56
# 56425            Pens & Art Supplies  26202.19497  Central     6.93
# 18829   Telephones and Communication   4072.26220    South  1151.36
# 6998              Chairs & Chairmats  12137.43480     West  3926.16
#
#         ship_date       ship_mode  shipping_cost       state unit_price  \
# 395483 2019-04-17     Express Air    2032.611597     Florida      99.99
# 970586 2021-11-18     Regular Air      37.289310        Ohio       6.48
# 56425  2020-03-15     Regular Air       5.099401       Texas       2.52
# 18829  2022-11-25  Delivery Truck     269.085711    Virginia      35.99
# 6998   2021-07-23     Express Air    2478.832163  Washington      95.95
#
#         zip_code
# 395483   32707.0
# 970586   45040.0
# 56425    78363.0
# 18829    24017.0
# 6998     98310.0
#
# [5 rows x 23 columns]

# %%
# Aggregate sales by date to remove duplicates
df = sample.groupby('order_date').agg({'sales': 'sum'}).reset_index()
#set index as date
df.set_index('order_date', inplace=True)

# %%
df.shape
# Out:
# (1461, 1)

# %%
df.head()
# Out:
#                sales
# order_date
# 2019-01-01  37659.47
# 2019-01-02  60052.86
# 2019-01-03  44292.47
# 2019-01-04  38410.81
# 2019-01-05  49022.58

# %%
df.tail()
# Out:
#                sales
# order_date
# 2022-12-27  47285.99
# 2022-12-28  51830.10
# 2022-12-29  34267.36
# 2022-12-30  30130.00
# 2022-12-31  26365.62

# %%
# Resample the data by month and calculate the sum of sales
df_monthly = df.resample('M').agg({'sales': 'sum'}).reset_index()

# If you need to add the monthly sum back to the original DataFrame
df['month_s'] = df['sales'].resample('M').transform('sum')

# Reset the index if necessary
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#   order_date     sales    month_s
# 0 2019-01-01  37659.47  1343560.4
# 1 2019-01-02  60052.86  1343560.4
# 2 2019-01-03  44292.47  1343560.4
# 3 2019-01-04  38410.81  1343560.4
# 4 2019-01-05  49022.58  1343560.4

# %%
df['month'] = df['order_date'].dt.to_period('M')

# %%
df.shape
# Out:
# (1461, 4)

# %%
df.set_index('month',inplace=True)

# %%
df.columns
# Out:
# Index(['order_date', 'sales', 'month_s'], dtype='object')

# %%
df.head()
# Out:
#         order_date     sales    month_s
# month
# 2019-01 2019-01-01  37659.47  1343560.4
# 2019-01 2019-01-02  60052.86  1343560.4
# 2019-01 2019-01-03  44292.47  1343560.4
# 2019-01 2019-01-04  38410.81  1343560.4
# 2019-01 2019-01-05  49022.58  1343560.4

# %%
df.describe()
# Out:
#                 order_date         sales       month_s
# count                 1461   1461.000000  1.461000e+03
# mean   2020-12-31 00:00:00  42367.232272  1.290293e+06
# min    2019-01-01 00:00:00  10094.370000  1.191165e+06
# 25%    2020-01-01 00:00:00  34597.650000  1.245993e+06
# 50%    2020-12-31 00:00:00  41852.380000  1.277333e+06
# 75%    2021-12-31 00:00:00  49834.300000  1.343560e+06
# max    2022-12-31 00:00:00  96667.820000  1.398021e+06
# std                    NaN  11602.351736  5.775347e+04

# %%
df.columns
# Out:
# Index(['order_date', 'sales', 'month_s'], dtype='object')

# %%
'''df=data.drop(['city', 'customer_age', 'customer_name', 'customer_segment', 'discount',
       'order_id', 'order_priority', 'order_quantity', 'product_base_margin',
       'product_category', 'product_container', 'product_name',
       'product_sub_category', 'profit', 'region', 'ship_date',
       'ship_mode', 'shipping_cost', 'state', 'unit_price', 'zip_code','order_date'],axis=1)'''
# Out:
# "df=data.drop(['city', 'customer_age', 'customer_name', 'customer_segment', 'discount',\n       'order_id', 'order_priority', 'order_quantity', 'product_base_margin',\n       'product_category', 'product_container', 'product_name',\n       'product_sub_category', 'profit', 'region', 'ship_date',\n       'ship_mode', 'shipping_cost', 'state', 'unit_price', 'zip_code','order_date'],axis=1)"

# %%
df.dtypes
# Out:
# order_date    datetime64[ns]
# sales                float64
# month_s              float64
# dtype: object

# %%
data3=df.drop(['order_date','sales'],axis=1)

# %%
data3.head()
# Out:
#            month_s
# month
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4

# %%
data3.plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ### Testing For Stationarity
# #### Augmented Dickey–Fuller test
# #Ho: It is non stationary
# #H1: It is stationary

# %%
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(data3['month_s'])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(data3['month_s'])
# Out:
# ADF Test Statistic : -5.508988812660367
# p-value : 1.9918552068475177e-06
# #Lags Used : 0
# Number of Observations Used : 1460
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
# from above steps we can say that time series is stationary

# %% [markdown]
# ### Autoregressive model

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(data3['month_s'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(data3['month_s'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(data3['month_s'].iloc[13:],lags=40,ax=ax2)

# %%
#For non-seasonal data
#p=1, d=1, q=0 or 1
from statsmodels.tsa.arima.model import ARIMA

# %%
data3.head()
# Out:
#            month_s
# month
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4
# 2019-01  1343560.4

# %%
model=ARIMA(data3['month_s'],order=(32,0,17))
model_fit=model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                month_s   No. Observations:                 1461
# Model:               ARIMA(32, 0, 17)   Log Likelihood              -16086.035
# Date:                Tue, 13 Aug 2024   AIC                          32274.069
# Time:                        16:49:01   BIC                          32543.700
# Sample:                    01-31-2019   HQIC                         32374.649
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.29e+06   1.06e+04    121.901      0.000    1.27e+06    1.31e+06
# ar.L1          0.9997      0.876      1.141      0.254      -0.717       2.717
# ar.L2         -0.0413      1.730     -0.024      0.981      -3.433       3.350
# ar.L3          0.0240      1.694      0.014      0.989      -3.297       3.344
# ar.L4         -0.0560      1.709     -0.033      0.974      -3.406       3.294
# ar.L5          0.1036      1.691      0.061      0.951      -3.212       3.419
# ar.L6         -0.1227      1.508     -0.081      0.935      -3.079       2.833
# ar.L7          0.1359      1.271      0.107      0.915      -2.354       2.626
# ar.L8         -0.1699      1.084     -0.157      0.875      -2.295       1.955
# ar.L9          0.1912      1.021      0.187      0.851      -1.810       2.192
# ar.L10        -0.2104      1.049     -0.201      0.841      -2.267       1.846
# ar.L11         0.2740      1.064      0.258      0.797      -1.811       2.359
# ar.L12        -0.2538      1.157     -0.219      0.826      -2.521       2.013
# ar.L13         0.1290      1.257      0.103      0.918      -2.335       2.593
# ar.L14        -0.1267      1.285     -0.099      0.921      -2.646       2.393
# ar.L15         0.1187      1.296      0.092      0.927      -2.421       2.659
# ar.L16         0.0836      1.209      0.069      0.945      -2.285       2.452
# ar.L17        -0.2294      0.893     -0.257      0.797      -1.980       1.521
# ar.L18         0.1244      0.397      0.313      0.754      -0.654       0.903
# ar.L19         0.0011      0.315      0.004      0.997      -0.616       0.619
# ar.L20         0.0004      0.339      0.001      0.999      -0.664       0.665
# ar.L21         0.0009      0.329      0.003      0.998      -0.645       0.646
# ar.L22        -0.0023      0.371     -0.006      0.995      -0.730       0.725
# ar.L23         0.0011      0.332      0.003      0.997      -0.649       0.651
# ar.L24         0.0003      0.352      0.001      0.999      -0.690       0.691
# ar.L25        -0.0018      0.357     -0.005      0.996      -0.701       0.698
# ar.L26         0.0043      0.362      0.012      0.991      -0.705       0.714
# ar.L27        -0.0041      0.354     -0.012      0.991      -0.698       0.690
# ar.L28        -0.0906      0.241     -0.377      0.706      -0.562       0.381
# ar.L29         0.0740      0.162      0.457      0.648      -0.243       0.391
# ar.L30        -0.2041      0.228     -0.895      0.371      -0.651       0.243
# ar.L31        -0.1312      0.388     -0.339      0.735      -0.891       0.628
# ar.L32         0.3293      0.280      1.178      0.239      -0.219       0.877
# ma.L1         -0.1202      0.877     -0.137      0.891      -1.838       1.598
# ma.L2         -0.0111      0.974     -0.011      0.991      -1.920       1.898
# ma.L3         -0.0366      0.909     -0.040      0.968      -1.819       1.745
# ma.L4          0.0579      0.989      0.058      0.953      -1.881       1.997
# ma.L5         -0.0567      0.948     -0.060      0.952      -1.914       1.801
# ma.L6          0.0835      0.815      0.103      0.918      -1.513       1.681
# ma.L7         -0.0692      0.692     -0.100      0.920      -1.425       1.286
# ma.L8          0.1204      0.595      0.202      0.840      -1.047       1.287
# ma.L9         -0.0973      0.627     -0.155      0.877      -1.326       1.131
# ma.L10         0.1415      0.565      0.250      0.802      -0.967       1.250
# ma.L11        -0.1737      0.602     -0.288      0.773      -1.354       1.007
# ma.L12         0.1311      0.700      0.187      0.851      -1.241       1.503
# ma.L13        -0.0259      0.717     -0.036      0.971      -1.431       1.380
# ma.L14         0.1236      0.729      0.170      0.865      -1.305       1.552
# ma.L15        -0.0299      0.750     -0.040      0.968      -1.500       1.440
# ma.L16        -0.1126      0.663     -0.170      0.865      -1.412       1.187
# ma.L17         0.1601      0.421      0.381      0.704      -0.665       0.985
# sigma2      2.041e+08   5.18e-05   3.94e+12      0.000    2.04e+08    2.04e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):            140051.43
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.71   Skew:                            -0.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                        50.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.9e+31. Standard errors may be unstable.
# """

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 1461 entries, 2019-01 to 2022-12
# Freq: M
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month_s  1461 non-null   float64
# dtypes: float64(1)
# memory usage: 22.8 KB

# %% [markdown]
# ### Check Duplicates

# %%
#There are duplicate value in index so we need to chaeck that
duplicates = data3.index.duplicated()
if duplicates.any():
    print("Duplicate indices found:\n", df3[duplicates])
else:
    print("No duplicate indices found.")
# Out:
# Duplicate indices found:
#             month_sum
# month
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# ...              ...
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
#
# [1413 rows x 1 columns]

# %%
# we have to remove duplicates from each index
df10 = data3[~data3.index.duplicated(keep='first')]
df11 = data3[~data3.index.duplicated(keep='first')]

# %%
df10.head()
# Out:
#             month_s
# month
# 2019-01  1343560.40
# 2019-02  1191165.38
# 2019-03  1270771.45
# 2019-04  1196374.88
# 2019-05  1320339.45

# %%
# Fit ARIMA model (example with order (1, 1, 1))
#model = ARIMA(df10['month_s'], order=(1, 1, 1))
#model_fit = model.fit()

# Forecast
df10['forecast'] = model_fit.predict(start=40, end=48, dynamic=True)

# Plot
df10[['month_s', 'forecast']].plot(figsize=(8, 6))
#plt.show()
# Out:
# <Axes: xlabel='month'>

# %%
model=sm.tsa.statespace.SARIMAX(df10['month_s'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()

# %%
df10['forecast']=results.predict(start=40,end=48,dynamic=True)
df10[['month_s','forecast']].plot(figsize=(8,6))
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ### Splitting Data & Forcasting on Test data
# #Train 90% & Test 10%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Assume df is your DataFrame with a 'Sales' column
# Splitting the data into training and testing sets
train_size = int(len(df10) * 0.9)  # 90% training, 10% testing
train, test = df10['month_s'][:train_size], df10['month_s'][train_size:]

# %%
start = len(train2)
end = len(train2) + len(test) - 1
forecast = model_fit.predict(start=start, end=end, dynamic=False)

# %%
# Assuming train, test, and forecast are your data series

# Convert PeriodIndex to DatetimeIndex if necessary
if isinstance(train.index, pd.PeriodIndex):
    train.index = train.index.to_timestamp()

if isinstance(test.index, pd.PeriodIndex):
    test.index = test.index.to_timestamp()

if isinstance(forecast.index, pd.PeriodIndex):
    forecast.index = forecast.index.to_timestamp()

# Plotting the actual vs predicted values
plt.figure(figsize=(12, 8))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test', color='blue')
plt.plot(test.index, forecast, label='Forecast', color='orange')
plt.title('ARIMA Model - Actual vs Forecast')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import r2_score
mae = mean_absolute_error(test, forecast)
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Absolute Error (MAE): 72609.26479651142
# Mean Squared Error (MSE): 6946816905.203486
# Root Mean Squared Error (RMSE): 83347.56688232408

# %% [markdown]
# ### For Entire Dataset

# %%
data2.shape
# Out:
# (1009318, 23)

# %%
# Aggregate sales by date to remove duplicates
df2 = data2.groupby('order_date').agg({'sales': 'sum'}).reset_index()
#set index as date
df2.set_index('order_date', inplace=True)

# %%
# Resample the data by month and calculate the sum of sales
df_monthly = df2.resample('M').agg({'sales': 'sum'}).reset_index()

# If you need to add the monthly sum back to the original DataFrame
df2['month_sum'] = df2['sales'].resample('M').transform('sum')

df2.reset_index(inplace=True)

# %%
df2.tail(10)
# Out:
#      order_date      sales    month_sum
# 1451 2022-12-22  853321.58  26725583.37
# 1452 2022-12-23  915536.53  26725583.37
# 1453 2022-12-24  824416.43  26725583.37
# 1454 2022-12-25  908115.05  26725583.37
# 1455 2022-12-26  882160.30  26725583.37
# 1456 2022-12-27  885005.04  26725583.37
# 1457 2022-12-28  860106.45  26725583.37
# 1458 2022-12-29  869793.52  26725583.37
# 1459 2022-12-30  914668.22  26725583.37
# 1460 2022-12-31  843658.57  26725583.37

# %%
df2['month'] = df2['order_date'].dt.to_period('M')

# %%
df2.head()
# Out:
#   order_date      sales    month_sum    month
# 0 2019-01-01  793877.16  26462081.13  2019-01
# 1 2019-01-02  909337.74  26462081.13  2019-01
# 2 2019-01-03  878111.88  26462081.13  2019-01
# 3 2019-01-04  796853.02  26462081.13  2019-01
# 4 2019-01-05  937855.53  26462081.13  2019-01

# %%
df2.set_index('month',inplace=True)

# %%
df2.columns
# Out:
# Index(['order_date', 'sales', 'month_sum'], dtype='object')

# %%
df2.tail(10)
# Out:
#         order_date      sales    month_sum
# month
# 2022-12 2022-12-22  853321.58  26725583.37
# 2022-12 2022-12-23  915536.53  26725583.37
# 2022-12 2022-12-24  824416.43  26725583.37
# 2022-12 2022-12-25  908115.05  26725583.37
# 2022-12 2022-12-26  882160.30  26725583.37
# 2022-12 2022-12-27  885005.04  26725583.37
# 2022-12 2022-12-28  860106.45  26725583.37
# 2022-12 2022-12-29  869793.52  26725583.37
# 2022-12 2022-12-30  914668.22  26725583.37
# 2022-12 2022-12-31  843658.57  26725583.37

# %%
df3=df2.drop(['order_date', 'sales'],axis=1)

# %%
df3.tail()
# Out:
#            month_sum
# month
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37

# %%
df3.plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ### Cheack Stationarity

# %%
test_result=adfuller(df3['month_sum'])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(month_sum):
    result=adfuller(month_sum)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df3['month_sum'])
# Out:
# ADF Test Statistic : -9.303232876809172
# p-value : 1.0980979904404834e-15
# #Lags Used : 24
# Number of Observations Used : 1436
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# ## Autoregressive model

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(df3['month_sum'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df3['month_sum'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df3['month_sum'].iloc[13:],lags=40,ax=ax2)

# %%
#For non-seasonal data
#p=1, d=1, q=0 or 1
from statsmodels.tsa.arima.model import ARIMA

# %%
df3.head()
# Out:
#            month_sum
# month
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13

# %%
model=ARIMA(df3['month_sum'],order=(10,0,29))
model_fit=model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              month_sum   No. Observations:                 1461
# Model:               ARIMA(10, 0, 29)   Log Likelihood              -20000.264
# Date:                Tue, 13 Aug 2024   AIC                          40082.527
# Time:                        16:56:19   BIC                          40299.289
# Sample:                    01-31-2019   HQIC                         40163.385
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.599e+07   3.62e-07   7.18e+13      0.000     2.6e+07     2.6e+07
# ar.L1          1.0962      0.898      1.220      0.222      -0.664       2.857
# ar.L2          0.0556      0.954      0.058      0.954      -1.814       1.925
# ar.L3          0.1661      0.228      0.730      0.465      -0.280       0.612
# ar.L4         -0.5239      0.224     -2.334      0.020      -0.964      -0.084
# ar.L5         -0.1457      0.450     -0.324      0.746      -1.028       0.737
# ar.L6          0.4922      0.239      2.055      0.040       0.023       0.962
# ar.L7         -0.0934      0.405     -0.231      0.818      -0.888       0.701
# ar.L8          0.0883      0.247      0.357      0.721      -0.397       0.573
# ar.L9         -0.2980      0.227     -1.312      0.190      -0.743       0.147
# ar.L10         0.1500      0.184      0.815      0.415      -0.211       0.511
# ma.L1         -0.1844      0.903     -0.204      0.838      -1.954       1.586
# ma.L2         -0.2336      0.189     -1.233      0.218      -0.605       0.138
# ma.L3         -0.4045      0.233     -1.734      0.083      -0.862       0.053
# ma.L4          0.2417      0.382      0.632      0.527      -0.508       0.991
# ma.L5          0.4010      0.200      2.002      0.045       0.009       0.793
# ma.L6         -0.1980      0.373     -0.531      0.595      -0.928       0.532
# ma.L7         -0.0909      0.201     -0.452      0.651      -0.485       0.303
# ma.L8         -0.1701      0.140     -1.219      0.223      -0.444       0.103
# ma.L9          0.2018      0.193      1.044      0.297      -0.177       0.581
# ma.L10         0.0310      0.148      0.209      0.835      -0.260       0.321
# ma.L11        -0.0258      0.102     -0.254      0.800      -0.225       0.173
# ma.L12        -0.0044      0.117     -0.038      0.970      -0.233       0.224
# ma.L13        -0.0140      0.118     -0.118      0.906      -0.246       0.218
# ma.L14         0.0210      0.132      0.159      0.873      -0.237       0.280
# ma.L15        -0.0078      0.122     -0.064      0.949      -0.246       0.230
# ma.L16         0.0052      0.127      0.041      0.967      -0.243       0.254
# ma.L17         0.0006      0.137      0.004      0.997      -0.268       0.269
# ma.L18        -0.0030      0.124     -0.024      0.981      -0.246       0.241
# ma.L19         0.0044      0.140      0.032      0.975      -0.269       0.278
# ma.L20        -0.0073      0.127     -0.058      0.954      -0.257       0.242
# ma.L21         0.0070      0.121      0.057      0.954      -0.231       0.245
# ma.L22        -0.0097      0.129     -0.075      0.940      -0.263       0.244
# ma.L23         0.0012      0.116      0.010      0.992      -0.226       0.228
# ma.L24        -0.0107      0.112     -0.095      0.924      -0.230       0.209
# ma.L25        -0.0276      0.109     -0.253      0.800      -0.242       0.187
# ma.L26        -0.0490      0.091     -0.539      0.590      -0.227       0.129
# ma.L27         0.0029      0.103      0.029      0.977      -0.198       0.204
# ma.L28        -0.4105      0.059     -6.985      0.000      -0.526      -0.295
# ma.L29         0.0102      0.387      0.026      0.979      -0.747       0.768
# sigma2      3.729e+10   1.79e-10   2.09e+20      0.000    3.73e+10    3.73e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            317892.23
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.72   Skew:                            -3.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                        75.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.67e+34. Standard errors may be unstable.
# """

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 1461 entries, 2019-01 to 2022-12
# Freq: M
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month_sum  1461 non-null   float64
# dtypes: float64(1)
# memory usage: 22.8 KB

# %%
df3.head()
# Out:
#            month_sum
# month
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13

# %%
#df4=df3.drop(['Sales First Difference','Seasonal First Difference'],axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 1461 entries, 2019-01 to 2022-12
# Freq: M
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month_sum  1461 non-null   float64
# dtypes: float64(1)
# memory usage: 22.8 KB

# %%
#There are duplicate value in index so we need to chaeck that
duplicates = df3.index.duplicated()
if duplicates.any():
    print("Duplicate indices found:\n", df3[duplicates])
else:
    print("No duplicate indices found.")
# Out:
# Duplicate indices found:
#             month_sum
# month
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# 2019-01  26462081.13
# ...              ...
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
# 2022-12  26725583.37
#
# [1413 rows x 1 columns]

# %%
# we have to remove duplicates from each index
df5 = df3[~df3.index.duplicated(keep='first')]
df4 = df3[~df3.index.duplicated(keep='first')]

# %%
df5.head()
# Out:
#            month_sum
# month
# 2019-01  26462081.13
# 2019-02  23262900.25
# 2019-03  26488513.31
# 2019-04  25966238.65
# 2019-05  26675574.93

# %%
df4.head()
# Out:
#            month_sum
# month
# 2019-01  26462081.13
# 2019-02  23262900.25
# 2019-03  26488513.31
# 2019-04  25966238.65
# 2019-05  26675574.93

# %%
#df5.to_csv('monthly_sales.csv',index=True)

# %%
# Fit ARIMA model (example with order (1, 1, 1))
model = ARIMA(df5['month_sum'], order=(1, 1, 1))
model_fit = model.fit()

# Forecast
df5['forecast'] = model_fit.predict(start=40, end=48, dynamic=True)

# Plot
df5[['month_sum', 'forecast']].plot(figsize=(8, 6))
#plt.show()
# Out:
# <Axes: xlabel='month'>

# %%
model=sm.tsa.statespace.SARIMAX(df5['month_sum'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()

# %%
df5['forecast']=results.predict(start=40,end=48,dynamic=True)
df5[['month_sum','forecast']].plot(figsize=(8,6))
# Out:
# <Axes: xlabel='month'>

# %%
df5.head()
# Out:
#            month_sum  forecast
# month
# 2019-01  26462081.13       NaN
# 2019-02  23262900.25       NaN
# 2019-03  26488513.31       NaN
# 2019-04  25966238.65       NaN
# 2019-05  26675574.93       NaN

# %% [markdown]
# ### try

# %%
# Assuming df5 contains your sales data and the last few months are for forecasting
#model = ARIMA(df5['month_sum'], order=(1, 1, 1))
#model_fit = model.fit()

# Forecast for a specific period
#forecast = model_fit.predict(start=len(df5), end=len(df5)+10, dynamic=True)

# Combine the original sales data with the forecast
#df5['forecast'] = forecast

# Plotting the results
#plt.figure(figsize=(12, 8))
#plt.plot(df5.index, df5['month_sum'], label='Sales', color='blue')
#plt.plot(df5.index, df5['forecast'], label='Forecast', color='orange')
#plt.legend(loc='best')
#plt.show()

# %%
# Convert PeriodIndex to DatetimeIndex
#df5.index = df5.index.to_timestamp()

# Now you can perform operations like forecasting and plotting
#model = ARIMA(df5['month_sum'], order=(1, 1, 1))
#model_fit = model.fit()

# Forecasting
#forecast = model_fit.predict(start=len(df5), end=len(df5)+10, dynamic=True)

# Combine the original sales data with the forecast
#df5['forecast'] = forecast

# %% [markdown]
# ### Splitting Data & Forcasting on Test data
# #Train 90% & Test 10%

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Assume df is your DataFrame with a 'Sales' column
# Splitting the data into training and testing sets
train_size = int(len(df5) * 0.9)  # 90% training, 10% testing
train, test = df5['month_sum'][:train_size], df5['month_sum'][train_size:]

# %%
start = len(train)
end = len(train) + len(test) - 1
forecast = model_fit.predict(start=start, end=end, dynamic=False)

# %%
# Convert PeriodIndex to DatetimeIndex
train.index = train.index.to_timestamp()
test.index = test.index.to_timestamp()
forecast.index = forecast.index.to_timestamp()
# Plotting the actual vs predicted values
plt.figure(figsize=(12, 8))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test', color='blue')
plt.plot(test.index, forecast, label='Forecast', color='orange')
plt.title('ARIMA Model - Actual vs Forecast')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import r2_score
mae = mean_absolute_error(test, forecast)
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Absolute Error (MAE): 775034.0583259345
# Mean Squared Error (MSE): 711441833733.1819
# Root Mean Squared Error (RMSE): 843470.1143094413
